# %% [markdown]
# # Introduction

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
recent_grads=pd.read_csv('recent-grads.csv')
recent_grads.iloc[0]
recent_grads.head()
recent_grads.tail()
recent_grads.describe()
raw_data_count=recent_grads.shape[0]
print(raw_data_count)
recent_grads=recent_grads.dropna()
cleaned_data_count=recent_grads.shape[0]
print(cleaned_data_count)
# Out:
# 173
# 172

# %% [markdown]
# # Pandas, Scatter Plots

# %%
ax=recent_grads.plot(x='Sample_size',y='Median',kind='scatter',title='',figsize=(5,10))

# %%
ax=recent_grads.plot(x='Sample_size',y='Unemployment_rate',kind='scatter',title='',figsize=(5,10))

# %%
ax=recent_grads.plot(x='Full_time',y='Median',kind='scatter',title='',figsize=(5,10))

# %%
ax=recent_grads.plot(x='ShareWomen',y='Unemployment_rate',kind='scatter',title='',figsize=(5,10))

# %%
ax=recent_grads.plot(x='Men',y='Median',kind='scatter',title='',figsize=(5,10))

# %%
ax=recent_grads.plot(x='Women',y='Median',kind='scatter',title='',figsize=(5,10))

# %% [markdown]
# # Pandas, Histograms

# %%
recent_grads['Sample_size'].plot(kind='hist')

# %%
recent_grads['Median'].plot(kind='hist')

# %%
recent_grads['Employed'].plot(kind='hist')

# %%
recent_grads['Full_time'].plot(kind='hist')

# %%
recent_grads['ShareWomen'].plot(kind='hist')

# %%
recent_grads['Unemployment_rate'].plot(kind='hist')

# %%
recent_grads['Men'].plot(kind='hist')

# %%
recent_grads['Women'].plot(kind='hist')
recent_grads['Women'].hist(bins=15, range=(0,500))

# %% [markdown]
# # Pandas, Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix 
scatter_matrix(recent_grads[['Sample_size','Median']], figsize=(10,10))
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f39e292d550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f39e290b940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f39e28c3780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f39e288ae80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f39e2846588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f39e280f7b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f39e27cf3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f39e2798710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f39e26e1748>]],
#       dtype=object)

# %% [markdown]
# # Pandas, Bar Plots

# %%
recent_grads[:10]['ShareWomen'].plot(kind='bar')
recent_grads[-10:]['ShareWomen'].plot(kind='bar')
recent_grads[:10]['Unemployment_rate'].plot(kind='bar')
recent_grads[-10:]['Unemployment_rate'].plot(kind='bar')
